# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_hq = pd.read_csv("./ds/Procedimiento1Hojadequirofano_20250424_iso-8859-1.csv", encoding="latin-1")
df_np = pd.read_csv("./ds/Procedimiento2NotaPostoperatoria_20250424.csv", encoding="latin-1")
df_hi = pd.read_csv("./ds/Procedimiento3Hojadeintervencionismo_20250424.csv", encoding="latin-1")

# %%
df_hq.shape
# Out:
# (271, 14)

# %%
df_hq.describe(include='object').transpose()
# Out:
#                                                    count unique  \
# Expediente / Paciente - Expediente Paciente - N...   266    224
# Expediente / Paciente - Expediente Paciente - N...   266    167
# Expediente / Paciente - Expediente Paciente - N...   266    173
# Fecha y Hora Registro                                271    261
# Fecha y Hora de Egreso                               271    261
# Fecha y hora de elaboración                          271    271
# Tipo de Ingreso                                      271      3
# Hospitalizado en                                     271     13
# Cirugí­a realizada - CIE 9 Tratamientos - Clave       92     26
# Cirugí­a realizada - CIE 9 Tratamientos - Descr...    92     24
# Clave                                                 92     26
# Descripción                                           92     24
#
#                                                                        top  \
# ...

# %%
df_hq.dtypes
# Out:
# ID Módulo Base                                                                            int64
# Expediente / Paciente - Expediente Paciente - Número de Expediente                      float64
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)               object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)      object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)     object
# Fecha y Hora Registro                                                                    object
# Fecha y Hora de Egreso                                                                   object
# Fecha y hora de elaboración                                                              object
# Tipo de Ingreso                                                                          object
# Hospitalizado en                                                                         object
# ...

# %%
df_hq["Hospitalizado en"].value_counts()
# Out:
# Hospitalizado en
# Servicio Clí­nico 8                      126
# Hospital de Dí­a                          67
# Servicio Clí­nico 2                       20
# Servicio Clí­nico 3                       12
# Servicio Clí­nico 4                       11
# Servicio Clí­nico 1                       10
#                                            9
# Servicio Clí­nico 10 Recuperación          4
# Servicio Clí­nico 10                       4
# Servicio Clí­nico 7                        3
# Quirófanos                                 2
# Servicio Clí­nico 10 Postquirúrgicos       2
# Unidad de Terapia Intermedia               1
# Name: count, dtype: int64
