# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# NumPy version: 2.2.5
# Pandas version: 2.2.3

# %%
df_hq = pd.read_csv("./ds/Procedimiento1Hojadequirofano_20250424_utf-8.csv")
df_np = pd.read_csv("./ds/Procedimiento2NotaPostoperatoria_20250424_utf-8.csv")
df_hi = pd.read_csv("./ds/Procedimiento3Hojadeintervencionismo_20250424_utf-8.csv")

# %% [markdown]
# ## Ajustar los datos de la Hoja de quirófano

# %%
df_hq.shape
# Out:
# (271, 14)

# %%
df_hq.describe(include='object').transpose()
# Out:
#                                                    count unique  \
# Expediente / Paciente - Expediente Paciente - N...   266    224
# Expediente / Paciente - Expediente Paciente - N...   266    167
# Expediente / Paciente - Expediente Paciente - N...   266    173
# Fecha y Hora Registro                                271    261
# Fecha y Hora de Egreso                               271    261
# Fecha y hora de elaboración                          271    271
# Tipo de Ingreso                                      271      3
# Hospitalizado en                                     271     13
# Cirugía realizada - CIE 9 Tratamientos - Clave        92     26
# Cirugía realizada - CIE 9 Tratamientos - Descri...    92     24
# Clave                                                 92     26
# Descripción                                           92     24
#
#                                                                        top  \
# Expediente / Paciente - Expediente Paciente - N...           MARCO ANTONIO
# Expediente / Paciente - Expediente Paciente - N...               HERNANDEZ
# Expediente / Paciente - Expediente Paciente - N...               HERNANDEZ
# Fecha y Hora Registro
# Fecha y Hora de Egreso
# Fecha y hora de elaboración                             30.Nov.23 11:20:00
# Tipo de Ingreso                                     ADMISIÓN HOSPITALARIA
# Hospitalizado en                                       Servicio Clínico 8
# Cirugía realizada - CIE 9 Tratamientos - Clave                        2188
# Cirugía realizada - CIE 9 Tratamientos - Descri...       Otra septoplastia
# Clave                                                                 2188
# Descripción                                              Otra septoplastia
#
#                                                    freq
# Expediente / Paciente - Expediente Paciente - N...    4
# Expediente / Paciente - Expediente Paciente - N...   13
# Expediente / Paciente - Expediente Paciente - N...   12
# Fecha y Hora Registro                                 9
# Fecha y Hora de Egreso                                9
# Fecha y hora de elaboración                           1
# Tipo de Ingreso                                     186
# Hospitalizado en                                    126
# Cirugía realizada - CIE 9 Tratamientos - Clave       16
# Cirugía realizada - CIE 9 Tratamientos - Descri...   16
# Clave                                                16
# Descripción                                          16

# %%
df_hq.dtypes
# Out:
# ID Módulo Base                                                                            int64
# Expediente / Paciente - Expediente Paciente - Número de Expediente                      float64
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)               object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)      object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)     object
# Fecha y Hora Registro                                                                    object
# Fecha y Hora de Egreso                                                                   object
# Fecha y hora de elaboración                                                              object
# Tipo de Ingreso                                                                          object
# Hospitalizado en                                                                         object
# Cirugía realizada - CIE 9 Tratamientos - Clave                                           object
# Cirugía realizada - CIE 9 Tratamientos - Descripción                                     object
# Clave                                                                                    object
# Descripción                                                                              object
# dtype: object

# %%
df_hq = df_hq.drop(columns = ['ID Módulo Base',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)',
                              'Cirugía realizada - CIE 9 Tratamientos - Clave',
                              'Cirugía realizada - CIE 9 Tratamientos - Descripción'])

# %%
df_hq.columns = ['Expediente', 'Registro', 'Egreso', 'Elaboracion', 'TipoIngreso', 'Servicio', 'Clave', 'Descripcion']

# %%
df_hq.info
# Out:
# <bound method DataFrame.info of      Expediente            Registro              Egreso         Elaboracion  \
# 0      248277.0  11.Ene.23 15:33:18  12.Ene.23 19:02:22  12.Ene.23 09:40:00
# 1      236422.0  11.Ene.23 15:48:18  12.Ene.23 19:05:18  12.Ene.23 08:41:00
# 2      209000.0  10.Ene.23 15:32:44  12.Ene.23 13:12:16  11.Ene.23 09:52:00
# 3      243590.0  10.Ene.23 15:23:31  11.Ene.23 18:02:14  11.Ene.23 10:56:00
# 4      248153.0  11.Ene.23 09:40:52  11.Ene.23 15:29:00  11.Ene.23 13:24:00
# ..          ...                 ...                 ...                 ...
# 266    216626.0  25.Oct.23 07:09:38  25.Oct.23 19:03:13  25.Oct.23 09:32:00
# 267         NaN                                          23.Oct.23 11:35:00
# 268    250094.0  23.Oct.23 11:08:32  25.Oct.23 14:59:41  24.Oct.23 10:45:00
# 269    239002.0  01.Nov.23 07:38:17  01.Nov.23 19:34:47  01.Nov.23 10:49:00
# 270    253011.0  29.Nov.23 15:11:54  03.Dic.23 16:27:53  30.Nov.23 11:20:00
#
#                     TipoIngreso             Servicio Clave  \
# 0        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 1        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 2        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    195
# 3        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 4    PROCEDIMIENTO AMBULATORIO           Quirófanos   3322
# ..                          ...                  ...   ...
# 266  PROCEDIMIENTO AMBULATORIO      Hospital de Día    NaN
# 267                                                    NaN
# 268      ADMISIÓN HOSPITALARIA   Servicio Clínico 4   3328
# 269  PROCEDIMIENTO AMBULATORIO      Hospital de Día    NaN
# 270      ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
#
#                    Descripcion
# 0                          NaN
# 1                          NaN
# 2          Otra timpanoplastia
# 3                          NaN
# 4     Broncoscopia fibroóptica
# ..                         ...
# 266                        NaN
# 267                        NaN
# 268  Biopsia abierta de pulmón
# 269                        NaN
# 270                        NaN
#
# [271 rows x 8 columns]>

# %%
df_hq.dropna(subset="Expediente").info
# Out:
# <bound method DataFrame.info of      Expediente            Registro              Egreso         Elaboracion  \
# 0      248277.0  11.Ene.23 15:33:18  12.Ene.23 19:02:22  12.Ene.23 09:40:00
# 1      236422.0  11.Ene.23 15:48:18  12.Ene.23 19:05:18  12.Ene.23 08:41:00
# 2      209000.0  10.Ene.23 15:32:44  12.Ene.23 13:12:16  11.Ene.23 09:52:00
# 3      243590.0  10.Ene.23 15:23:31  11.Ene.23 18:02:14  11.Ene.23 10:56:00
# 4      248153.0  11.Ene.23 09:40:52  11.Ene.23 15:29:00  11.Ene.23 13:24:00
# ..          ...                 ...                 ...                 ...
# 265    253651.0  09.Oct.23 12:51:02  28.Oct.23 14:13:57  17.Oct.23 11:00:00
# 266    216626.0  25.Oct.23 07:09:38  25.Oct.23 19:03:13  25.Oct.23 09:32:00
# 268    250094.0  23.Oct.23 11:08:32  25.Oct.23 14:59:41  24.Oct.23 10:45:00
# 269    239002.0  01.Nov.23 07:38:17  01.Nov.23 19:34:47  01.Nov.23 10:49:00
# 270    253011.0  29.Nov.23 15:11:54  03.Dic.23 16:27:53  30.Nov.23 11:20:00
#
#                     TipoIngreso             Servicio Clave  \
# 0        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 1        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 2        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    195
# 3        ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
# 4    PROCEDIMIENTO AMBULATORIO           Quirófanos   3322
# ..                          ...                  ...   ...
# 265      ADMISIÓN HOSPITALARIA   Servicio Clínico 2   3241
# 266  PROCEDIMIENTO AMBULATORIO      Hospital de Día    NaN
# 268      ADMISIÓN HOSPITALARIA   Servicio Clínico 4   3328
# 269  PROCEDIMIENTO AMBULATORIO      Hospital de Día    NaN
# 270      ADMISIÓN HOSPITALARIA   Servicio Clínico 8    NaN
#
#                                Descripcion
# 0                                      NaN
# 1                                      NaN
# 2                      Otra timpanoplastia
# 3                                      NaN
# 4                 Broncoscopia fibroóptica
# ..                                     ...
# 265  Lobectomía de pulmón por toracoscopía
# 266                                    NaN
# 268              Biopsia abierta de pulmón
# 269                                    NaN
# 270                                    NaN
#
# [266 rows x 8 columns]>

# %% [markdown]
# ## Ajustar datos de la Nota postoperatoria

# %%
df_np.shape
# Out:
# (1000, 14)

# %%
df_np.describe(include='object').transpose()
# Out:
#                                                    count unique  \
# Expediente / Paciente - Expediente Paciente - N...  1000    734
# Expediente / Paciente - Expediente Paciente - N...  1000    559
# Expediente / Paciente - Expediente Paciente - N...  1000    355
# Expediente / Paciente - Expediente Paciente - N...   987    374
# Expediente / Paciente - Expediente Paciente - F...  1000    726
# Fecha y Hora Registro                               1000    766
# Fecha y Hora de Egreso                              1000    766
# Fecha y hora de Elaboración                         1000    954
# Tipo de Ingreso                                     1000      4
# Hospitalizado en                                    1000     12
# Cirugía Realizada                                   1000    703
# Clave                                               1000    220
# Descripción                                         1000    213
#
#                                                                                                   top  \
# Expediente / Paciente - Expediente Paciente - N...                                             230563
# Expediente / Paciente - Expediente Paciente - N...                                          ALEJANDRO
# Expediente / Paciente - Expediente Paciente - N...                                          HERNANDEZ
# Expediente / Paciente - Expediente Paciente - N...                                          HERNANDEZ
# Expediente / Paciente - Expediente Paciente - F...                                         1992-08-05
# Fecha y Hora Registro
# Fecha y Hora de Egreso
# Fecha y hora de Elaboración                                                        28.Mar.23 14:47:30
# Tipo de Ingreso                                                                ADMISIÓN HOSPITALARIA
# Hospitalizado en                                                                  Servicio Clínico 8
# Cirugía Realizada                                   RINOSEPTUMPLASTIA FUNCIONAL + ABLACIÓN DE CORN...
# Clave                                                                                            3142
# Descripción                                                        Laringoscopia y otra traqueoscopia
#
#                                                    freq
# Expediente / Paciente - Expediente Paciente - N...    6
# Expediente / Paciente - Expediente Paciente - N...   10
# Expediente / Paciente - Expediente Paciente - N...   40
# Expediente / Paciente - Expediente Paciente - N...   33
# Expediente / Paciente - Expediente Paciente - F...    6
# Fecha y Hora Registro                                57
# Fecha y Hora de Egreso                               57
# Fecha y hora de Elaboración                           4
# Tipo de Ingreso                                     778
# Hospitalizado en                                    555
# Cirugía Realizada                                    29
# Clave                                                82
# Descripción                                          82

# %%
df_np.dtypes
# Out:
# ID Módulo Base                                                                           int64
# Expediente / Paciente - Expediente Paciente - Número de Expediente                      object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)              object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)     object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)    object
# Expediente / Paciente - Expediente Paciente - Fecha de nacimiento                       object
# Fecha y Hora Registro                                                                   object
# Fecha y Hora de Egreso                                                                  object
# Fecha y hora de Elaboración                                                             object
# Tipo de Ingreso                                                                         object
# Hospitalizado en                                                                        object
# Cirugía Realizada                                                                       object
# Clave                                                                                   object
# Descripción                                                                             object
# dtype: object

# %%
df_np = df_np.drop(columns = ['ID Módulo Base',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)',
                              'Expediente / Paciente - Expediente Paciente - Fecha de nacimiento',
                              'Cirugía Realizada'])

# %%
df_np.columns = ['Expediente', 'Registro', 'Egreso', 'Elaboracion', 'TipoIngreso', 'Servicio', 'Clave', 'Descripcion']

# %%
df_np.info
# Out:
# <bound method DataFrame.info of     Expediente            Registro              Egreso         Elaboracion  \
# 0       248277  11.Ene.23 15:33:18  12.Ene.23 19:02:22  12.Ene.23 10:42:53
# 1       244031  12.Ene.23 07:58:13  13.Ene.23 11:39:03  12.Ene.23 19:48:34
# 2       243588  13.Ene.23 06:38:20  13.Ene.23 18:23:57  13.Ene.23 13:27:52
# 3       246542  23.Ene.23 15:36:55  25.Ene.23 10:07:23  24.Ene.23 11:03:20
# 4       204124  24.Ene.23 15:41:32  26.Ene.23 10:53:46  25.Ene.23 11:11:58
# ..         ...                 ...                 ...                 ...
# 995     254692  24.Nov.23 01:43:36  22.Dic.23 17:12:51  01.Dic.23 16:20:38
# 996     221315  01.Dic.23 06:48:57  01.Dic.23 16:47:31  01.Dic.23 16:35:17
# 997     246005  01.Dic.23 07:47:57  03.Dic.23 09:24:55  01.Dic.23 17:49:00
# 998     253871  30.Nov.23 15:32:50  02.Dic.23 11:53:39  01.Dic.23 18:17:40
# 999     250693  06.Nov.23 18:18:13  16.Dic.23 18:00:56  02.Dic.23 14:30:46
#
#                     TipoIngreso              Servicio Clave  \
# 0        ADMISIÓN HOSPITALARIA    Servicio Clínico 8   6731
# 1        ADMISIÓN HOSPITALARIA   Servicio Clínico 10   2199
# 2    PROCEDIMIENTO AMBULATORIO       Hospital de Día    219
# 3        ADMISIÓN HOSPITALARIA    Servicio Clínico 8   3142
# 4        ADMISIÓN HOSPITALARIA    Servicio Clínico 8    215
# ..                          ...                   ...   ...
# 995      ADMISIÓN HOSPITALARIA    Servicio Clínico 1   3406
# 996  PROCEDIMIENTO AMBULATORIO       Hospital de Día   3322
# 997      ADMISIÓN HOSPITALARIA    Servicio Clínico 8   3142
# 998      ADMISIÓN HOSPITALARIA    Servicio Clínico 8   2122
# 999      ADMISIÓN HOSPITALARIA    Servicio Clínico 9   5122
#
#                                            Descripcion
# 0                  Marsupialización de quiste cervical
# 1                        Otra operación sobre la nariz
# 2                     Otras operaciones sobre la nariz
# 3                   Laringoscopia y otra traqueoscopia
# 4    Resección submucosa del tabique nasal (septopl...
# ..                                                 ...
# 995        Drenaje de cavidad pleural por toracoscopía
# 996                           Broncoscopia fibroóptica
# 997                 Laringoscopia y otra traqueoscopia
# 998                                   Biopsia de nariz
# 999                                    Colecistectomía
#
# [1000 rows x 8 columns]>

# %%
df_np.dropna(subset="Expediente").info
# Out:
# <bound method DataFrame.info of     Expediente            Registro              Egreso         Elaboracion  \
# 0       248277  11.Ene.23 15:33:18  12.Ene.23 19:02:22  12.Ene.23 10:42:53
# 1       244031  12.Ene.23 07:58:13  13.Ene.23 11:39:03  12.Ene.23 19:48:34
# 2       243588  13.Ene.23 06:38:20  13.Ene.23 18:23:57  13.Ene.23 13:27:52
# 3       246542  23.Ene.23 15:36:55  25.Ene.23 10:07:23  24.Ene.23 11:03:20
# 4       204124  24.Ene.23 15:41:32  26.Ene.23 10:53:46  25.Ene.23 11:11:58
# ..         ...                 ...                 ...                 ...
# 995     254692  24.Nov.23 01:43:36  22.Dic.23 17:12:51  01.Dic.23 16:20:38
# 996     221315  01.Dic.23 06:48:57  01.Dic.23 16:47:31  01.Dic.23 16:35:17
# 997     246005  01.Dic.23 07:47:57  03.Dic.23 09:24:55  01.Dic.23 17:49:00
# 998     253871  30.Nov.23 15:32:50  02.Dic.23 11:53:39  01.Dic.23 18:17:40
# 999     250693  06.Nov.23 18:18:13  16.Dic.23 18:00:56  02.Dic.23 14:30:46
#
#                     TipoIngreso              Servicio Clave  \
# 0        ADMISIÓN HOSPITALARIA    Servicio Clínico 8   6731
# 1        ADMISIÓN HOSPITALARIA   Servicio Clínico 10   2199
# 2    PROCEDIMIENTO AMBULATORIO       Hospital de Día    219
# 3        ADMISIÓN HOSPITALARIA    Servicio Clínico 8   3142
# 4        ADMISIÓN HOSPITALARIA    Servicio Clínico 8    215
# ..                          ...                   ...   ...
# 995      ADMISIÓN HOSPITALARIA    Servicio Clínico 1   3406
# 996  PROCEDIMIENTO AMBULATORIO       Hospital de Día   3322
# 997      ADMISIÓN HOSPITALARIA    Servicio Clínico 8   3142
# 998      ADMISIÓN HOSPITALARIA    Servicio Clínico 8   2122
# 999      ADMISIÓN HOSPITALARIA    Servicio Clínico 9   5122
#
#                                            Descripcion
# 0                  Marsupialización de quiste cervical
# 1                        Otra operación sobre la nariz
# 2                     Otras operaciones sobre la nariz
# 3                   Laringoscopia y otra traqueoscopia
# 4    Resección submucosa del tabique nasal (septopl...
# ..                                                 ...
# 995        Drenaje de cavidad pleural por toracoscopía
# 996                           Broncoscopia fibroóptica
# 997                 Laringoscopia y otra traqueoscopia
# 998                                   Biopsia de nariz
# 999                                    Colecistectomía
#
# [1000 rows x 8 columns]>

# %% [markdown]
# ## Ajustar datos de la Hoja de intervencionismo

# %%
df_hi.shape
# Out:
# (898, 14)

# %%
df_hi.describe(include='object').transpose()
# Out:
#                                                    count unique  \
# Expediente / Paciente - Expediente Paciente - N...   898    621
# Expediente / Paciente - Expediente Paciente - N...   898    463
# Expediente / Paciente - Expediente Paciente - N...   898    310
# Expediente / Paciente - Expediente Paciente - N...   893    340
# Fecha y Hora Registro                                898    728
# Fecha y Hora de Egreso                               898    720
# Fecha y hora de elaboración                          898    893
# Tipo de Ingreso                                      898      4
# Hospitalizado en                                     898     14
# Procedimiento realizado - CIE 9 Tratamientos - ...   701     24
# Descripción                                          701     24
#
#                                                                            top  \
# Expediente / Paciente - Expediente Paciente - N...                      210636
# Expediente / Paciente - Expediente Paciente - N...                       MARIA
# Expediente / Paciente - Expediente Paciente - N...                   HERNANDEZ
# Expediente / Paciente - Expediente Paciente - N...                      GARCIA
# Fecha y Hora Registro
# Fecha y Hora de Egreso
# Fecha y hora de elaboración                                 18.Sep.23 11:30:00
# Tipo de Ingreso                                     PROCEDIMIENTO AMBULATORIO
# Hospitalizado en                                              Hospital de Día
# Procedimiento realizado - CIE 9 Tratamientos - ...    Broncoscopia fibroóptica
# Descripción                                           Broncoscopia fibroóptica
#
#                                                    freq
# Expediente / Paciente - Expediente Paciente - N...   13
# Expediente / Paciente - Expediente Paciente - N...   20
# Expediente / Paciente - Expediente Paciente - N...   35
# Expediente / Paciente - Expediente Paciente - N...   37
# Fecha y Hora Registro                               134
# Fecha y Hora de Egreso                              144
# Fecha y hora de elaboración                           2
# Tipo de Ingreso                                     542
# Hospitalizado en                                    330
# Procedimiento realizado - CIE 9 Tratamientos - ...  551
# Descripción                                         551

# %%
df_hi.dtypes
# Out:
# ID Módulo Base                                                                            int64
# Expediente / Paciente - Expediente Paciente - Número de Expediente                       object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)               object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)      object
# Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)     object
# Fecha y Hora Registro                                                                    object
# Fecha y Hora de Egreso                                                                   object
# Fecha y hora de elaboración                                                              object
# Tipo de Ingreso                                                                          object
# Hospitalizado en                                                                         object
# Procedimiento realizado - CIE 9 Tratamientos - Clave                                    float64
# Procedimiento realizado - CIE 9 Tratamientos - Descripción                               object
# Clave                                                                                   float64
# Descripción                                                                              object
# dtype: object

# %%
df_hi = df_hi.drop(columns = ['ID Módulo Base',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Nombre)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Primer Apellido)',
                              'Expediente / Paciente - Expediente Paciente - Nombre del Paciente (Segundo Apellido)',
                              'Procedimiento realizado - CIE 9 Tratamientos - Clave',
                              'Procedimiento realizado - CIE 9 Tratamientos - Descripción'])

# %%
df_hi.columns = ['Expediente', 'Registro', 'Egreso', 'Elaboracion', 'TipoIngreso', 'Servicio', 'Clave', 'Descripcion']

# %%
df_hi.info
# Out:
# <bound method DataFrame.info of     Expediente            Registro              Egreso         Elaboracion  \
# 0       247800  20.Dic.22 08:04:34  20.Dic.22 17:20:14  20.Dic.22 12:05:00
# 1       167293  02.Feb.23 08:02:32  02.Feb.23 15:54:18  02.Feb.23 10:02:00
# 2       240491  02.Feb.23 07:51:01  02.Feb.23 15:53:54  02.Feb.23 11:35:00
# 3       246336  02.Feb.23 06:46:43  02.Feb.23 15:54:52  02.Feb.23 08:55:00
# 4       242564  07.Ene.23 14:25:46  08.Feb.23 14:45:52  02.Feb.23 13:00:00
# ..         ...                 ...                 ...                 ...
# 893     255678  25.Ene.24 07:41:20  25.Ene.24 13:29:07  25.Ene.24 12:46:00
# 894     251834  29.Ene.24 07:04:48  29.Ene.24 11:43:19  29.Ene.24 10:43:00
# 895     255830  01.Feb.24 06:44:56  01.Feb.24 12:12:32  01.Feb.24 10:03:00
# 896     253057  01.Feb.24 08:25:49  01.Feb.24 15:39:47  01.Feb.24 11:54:00
# 897     259448  11.Jun.24 18:26:14  10.Jul.24 16:33:00  11.Jun.24 17:55:00
#
#                     TipoIngreso                        Servicio   Clave  \
# 0    PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 1    PROCEDIMIENTO AMBULATORIO   Broncoscopia Intervencionista      NaN
# 2    PROCEDIMIENTO AMBULATORIO   Broncoscopia Intervencionista      NaN
# 3    PROCEDIMIENTO AMBULATORIO                 Hospital de Día      NaN
# 4        ADMISIÓN HOSPITALARIA              Servicio Clínico 3    311.0
# ..                          ...                             ...     ...
# 893  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 894  PROCEDIMIENTO AMBULATORIO                 Hospital de Día      NaN
# 895  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 896  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 897      ADMISIÓN HOSPITALARIA              Servicio Clínico 3      NaN
#
#                   Descripcion
# 0    Broncoscopia fibroóptica
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4      Traqueostomía temporal
# ..                        ...
# 893  Broncoscopia fibroóptica
# 894                       NaN
# 895  Broncoscopia fibroóptica
# 896  Broncoscopia fibroóptica
# 897                       NaN
#
# [898 rows x 8 columns]>

# %%
df_hi.dropna(subset="Expediente").info
# Out:
# <bound method DataFrame.info of     Expediente            Registro              Egreso         Elaboracion  \
# 0       247800  20.Dic.22 08:04:34  20.Dic.22 17:20:14  20.Dic.22 12:05:00
# 1       167293  02.Feb.23 08:02:32  02.Feb.23 15:54:18  02.Feb.23 10:02:00
# 2       240491  02.Feb.23 07:51:01  02.Feb.23 15:53:54  02.Feb.23 11:35:00
# 3       246336  02.Feb.23 06:46:43  02.Feb.23 15:54:52  02.Feb.23 08:55:00
# 4       242564  07.Ene.23 14:25:46  08.Feb.23 14:45:52  02.Feb.23 13:00:00
# ..         ...                 ...                 ...                 ...
# 893     255678  25.Ene.24 07:41:20  25.Ene.24 13:29:07  25.Ene.24 12:46:00
# 894     251834  29.Ene.24 07:04:48  29.Ene.24 11:43:19  29.Ene.24 10:43:00
# 895     255830  01.Feb.24 06:44:56  01.Feb.24 12:12:32  01.Feb.24 10:03:00
# 896     253057  01.Feb.24 08:25:49  01.Feb.24 15:39:47  01.Feb.24 11:54:00
# 897     259448  11.Jun.24 18:26:14  10.Jul.24 16:33:00  11.Jun.24 17:55:00
#
#                     TipoIngreso                        Servicio   Clave  \
# 0    PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 1    PROCEDIMIENTO AMBULATORIO   Broncoscopia Intervencionista      NaN
# 2    PROCEDIMIENTO AMBULATORIO   Broncoscopia Intervencionista      NaN
# 3    PROCEDIMIENTO AMBULATORIO                 Hospital de Día      NaN
# 4        ADMISIÓN HOSPITALARIA              Servicio Clínico 3    311.0
# ..                          ...                             ...     ...
# 893  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 894  PROCEDIMIENTO AMBULATORIO                 Hospital de Día      NaN
# 895  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 896  PROCEDIMIENTO AMBULATORIO                 Hospital de Día   3322.0
# 897      ADMISIÓN HOSPITALARIA              Servicio Clínico 3      NaN
#
#                   Descripcion
# 0    Broncoscopia fibroóptica
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4      Traqueostomía temporal
# ..                        ...
# 893  Broncoscopia fibroóptica
# 894                       NaN
# 895  Broncoscopia fibroóptica
# 896  Broncoscopia fibroóptica
# 897                       NaN
#
# [898 rows x 8 columns]>

# %% [markdown]
# ## Descripción

# %%
df_np["Servicio"].value_counts()
# Out:
# Servicio
# Servicio Clínico 8                   555
# Hospital de Día                      137
# Servicio Clínico 1                    60
# Servicio Clínico 3                    58
#                                       57
# Servicio Clínico 4                    46
# Servicio Clínico 2                    39
# Servicio Clínico 7                    28
# Unidad de Terapia Intermedia          10
# Servicio Clínico 9                     7
# Servicio Clínico 10 Recuperación       2
# Servicio Clínico 10                    1
# Name: count, dtype: int64

# %%
df_np.describe().transpose()
# Out:
#             count unique                                 top freq
# Expediente   1000    734                              230563    6
# Registro     1000    766                                       57
# Egreso       1000    766                                       57
# Elaboracion  1000    954                  28.Mar.23 14:47:30    4
# TipoIngreso  1000      4              ADMISIÓN HOSPITALARIA   778
# Servicio     1000     12                 Servicio Clínico 8   555
# Clave        1000    220                                3142   82
# Descripcion  1000    213  Laringoscopia y otra traqueoscopia   82
